# %% [markdown]
# *Written by Gregory Palermo, 2018-06-29*
#
# This notebook parses the RSS feeds of a dictionary of news sources and accumulates recent headlines (not sure what the window is, to be honest). The hope is that we can run this periodically and collect headlines, searching them for detention-center-relevant content to provide a live feed.
#
# We may also be able to do this for article summaries, provided that field is in use by the publications. (Not quite sure how to do that, but I'm not all that familiar with the `feedparser` package.
#
# Unfortunately, RSS feeds do not include the full text of the articles, which must be scraped otherwise.

# %%
import feedparser

# Function to fetch the rss feed and return the parsed RSS
def parseRSS(rss_url):
    return feedparser.parse(rss_url) 
    
# Function grabs the rss feed headlines (titles) and returns them as a list
def getHeadlines(rss_url):
    headlines = []
    
    feed = parseRSS(rss_url)
    for newsitem in feed['items']:
        headlines.append(newsitem['title'])
    
    return headlines

def getSummaries(rss_url):
    summaries = []
    
    feed = parseRSS(rss_url)
    for newsitem in feed['items']:
        summaries.append(newsitem['summary'])
    

allheadlines = []
 
# Dictionary of RSS feeds to fetch and combine (this is just a random sample, to test)
newsurls = {
    'apnews':           'http://hosted2.ap.org/atom/APDEFAULT/3d281c11a96b4ad082fe88aa0db04305',
    'googlenews':       'https://news.google.com/news/rss/?hl=en&amp;ned=us&amp;gl=US',
    'yahoonews':        'http://news.yahoo.com/rss/',
    'Chillicothe Gazette' : 'http://rssfeeds.chillicothegazette.com/chillicothe/news',
    'Cincinnati.com' : 'http://rssfeeds.cincinnati.com/cincinnati-news',
    'Chocton Tribune' : 'http://rssfeeds.coshoctontribune.com/coshocton/news',
    'The News-Messenger, Fremont' : 'http://rssfeeds.thenews-messenger.com/fremont/news',
    'Lancaster Eagle-Gazette' : 'http://rssfeeds.lancastereaglegazette.com/lancaster/news',
    'Mansfield News Journal' : 'http://rssfeeds.mansfieldnewsjournal.com/mansfield/news',
    'The Marion Star' : 'http://rssfeeds.marionstar.com/marion/news',
    'The Advocate, Newark' : 'http://rssfeeds.newarkadvocate.com/newark/news',
    'News Herald, Port Clinton' : 'http://rssfeeds.portclintonnewsherald.com/portclinton/news',
    'Times Recorder, Zanesville' : 'http://rssfeeds.zanesvilletimesrecorder.com/zanesville/news',
    'Statesman Journal, Salem' : 'http://rssfeeds.statesmanjournal.com/salem/news',
    'Chambersburg Public Opinion' : 'http://rssfeeds.publicopiniononline.com/publicopiniononline/news',
    'Hanover Evening Sun' : 'http://rssfeeds.eveningsun.com/hanover/news',
    'Lebanon Daily News' : 'http://rssfeeds.ldnews.com/lebanon/news',
    'York Daily Record' : 'http://rssfeeds.ydr.com/ydr/home',
    'The Anderson Independent-Mail' : 'http://rssfeeds.independentmail.com/anderson/news',
    'GreenvilleOnline.com' : 'http://rssfeeds.greenvilleonline.com/greenville/news',
    'Argus Leader, Sioux Falls' : 'http://rssfeeds.argusleader.com/siouxfalls/news',
    'The Commercial Appeal (Memphis)' : 'http://rssfeeds.commercialappeal.com/memphis/news',
    'The Knoxville News-Sentinel' : 'http://rssfeeds.knoxnews.com/knoxville/news',
    'The Leaf-Chronicle, Clarksville' : 'http://rssfeeds.theleafchronicle.com/clarksville/news',
    'The Jackson Sun' : 'http://rssfeeds.jacksonsun.com/jacksontn/news',
    'The Daily News Journal, Murfreesboro' : 'http://rssfeeds.dnj.com/murfreesboro/news',
    'The Tennessean, Nashville' : 'http://rssfeeds.tennessean.com/nashville/news',
    'The Abilene Reporter-News' : 'http://rssfeeds.reporternews.com/abilene/news',
    'The Corpus Christi Caller Times' : 'http://rssfeeds.caller.com/corpuschristi/news/',
    'El Paso Times' : 'http://rssfeeds.elpasotimes.com/elpaso/news',
    'The San Angelo Standard-Times' : 'http://rssfeeds.gosanangelo.com/sanangelo/news',
    'Times Record News (Wichita Falls)' : 'http://rssfeeds.timesrecordnews.com/wichitafalls/news',
    'The Spectrum, St. George' : 'http://rssfeeds.thespectrum.com/stgeorge/news',
    'The Burlington Free Press' : 'http://rssfeeds.burlingtonfreepress.com/burlington/home',
    'The News Leader, Staunton' : 'http://rssfeeds.newsleader.com/staunton-news',
    'Kitsap Sun (Bremerton)' : 'http://rssfeeds.kitsapsun.com/kitsapnews',
    'The Post-Crescent, Appleton' : 'http://rssfeeds.postcrescent.com/appleton/news',
    'The Reporter, Fond du Lac' : 'http://rssfeeds.fdlreporter.com/fonddulac/news',
    'Green Bay Press-Gazette' : 'http://rssfeeds.greenbaypressgazette.com/greenbay/news',
    'Herald Times Reporter, Manitowoc' : 'http://rssfeeds.htrnews.com/manitowoc/news',
    'Marshfield News Herald' : 'http://rssfeeds.marshfieldnewsherald.com/marshfield/news',
    'Milwaukee Journal Sentinel' : 'http://rssfeeds.jsonline.com/milwaukee/news',
    'Oshkosh Northwestern' : 'http://rssfeeds.thenorthwestern.com/oshkosh/news',
    'The Sheboygan Press' : 'http://rssfeeds.sheboyganpress.com/sheboygan/news',
    'Stevens Point Journal' : 'http://rssfeeds.stevenspointjournal.com/stevenspoint/news',
    'Wausau Daily Herald' : 'http://rssfeeds.wausaudailyherald.com/wausau/news',
    'The Daily Tribune, Wisconsin Rapids' : 'http://rssfeeds.wisconsinrapidstribune.com/wisconsinrapids/news'    
}

# Iterate over the feed urls in the dictionary
for key,url in newsurls.items():
    # Call getHeadlines() and combine the returned headlines with allheadlines
    allheadlines.extend( getHeadlines( url ) )

# %%
allheadlines
# Out:
# ['Coast-to-coast protests denounce Trump immigration policies',
#  'Supreme Court Abortion Rights Threat Will Be Election Boost for Democrats: Poll',
#  'Abolishing ICE becomes Dem litmus test',
#  "LUPICA: Journalists aren't 'the enemy of the people' — guns are",
#  "US envoy to Estonia says he has resigned, citing Trump's treatment of European allies",
#  "Thieves emptied the bank account of America's oldest living veteran",
#  'Trump Supporters not Welcome in Canada? Manager Fired After Refusing to Serve MAGA Cap Customer',
#  'Kylian Mbappé retired Javier Mascherano',
#  'Mom Who Accidentally Left Daughter In Hot Car To Die Begged Jail Guards To Let Her Kill Herself, Lawyer Says',
#  'Trump says Saudi king agreed to raise oil output by up to 2 million barrels',
#  'Neighbors who call police on 12-year-old mowing lawn increase his business, customer says',
#  "Iran's leaders seek ways to defend economy from US sanctions",
#  '$1 million nationwide warrant issued for Washington man sought in beheading death',
#  'Dangerous heat wave hitting US over Fourth of July weekend',
#  "Obama offers Democrats tough love ahead of midterms: 'Enough moping'",
#  'Autistic Georgia girl, 16, who may have runaway with older man found safe, report says',
#  "There Were Zero Things Better This Week Than Alexandria Ocasio-Cortez's Victory Face",
#  "'I Beg Skies to Show Mercy': Thais Rally Behind Cave Rescue",
#  'Police use of Taser on unarmed black man in Pennsylvania spurs protests',
#  "Here Are The Best 'Families Belong Together' March Signs",
#  'Kirsten Gillibrand, Bill De Blasio Call To Abolish ICE',
#  'Larry Nassar And Trainer Debbie Van Horn Charged With Child Sexual Abuse',
#  'The coming war over Trump&apos;s next Supreme Court nominee',
#  'The Dark Parts Of The Internet Are Celebrating The Capital Gazette Slayings',
#  'Smirnoff Ice wants to pay you to take a week off for the Fourth of July',
#  'Here&apos;s A Look At Disney World’s Toy Story Land',
#  'As Thai search enters seventh day, divers cling to hope of finding lost boys',
#  'Bali volcano erupts: Thousands of tourists stranded as ash closes airport',
#  '“Hard to believe it’s over”: The last days of an American dairy farm',
#  'Maverick entrepreneur&#39;s space rocket fails at blast off',
#  'Protesters Block Expressway After Officer Who Shot Antwon Rose Granted Bail',
#  'Donald Trump&apos;s insults to European allies prompts US ambassador to Estonia to resign',
#  'New details released in Maryland newspaper shooting',
#  'These Are The Victims Of The Capital Gazette Shooting',
#  '9 detained, officers reopen immigration office in Oregon',
#  'Police Chief On Annapolis Shooting Suspect: &apos;I Will Not Say His Name Today&apos;',
#  'Passenger Tossed From Flight in Dispute With Flight Attendant Over Airplane Mode in Indiana',
#  'Revellers battle it out with wine in Spain',
#  'Hezbollah says &#39;very big victory&#39; imminent in south Syria',
#  'I Call BS On Needing $1 Million To Retire (And Other Bad Retirement &apos;Rules&apos;)',
#  'Turkey condemns Syria regime&#39;s &#39;inhuman&#39; assault on Daraa',
#  'Two New Russian Stealth Submarines Are Headed to the Pacific. Here Is What They Can Do.',
#  'Sean Hannity Blames Maxine Waters For Capital Gazette Shooting',
#  'Trump to move quickly on Supreme Court nominee',
#  'Justice for Junior: 7 suspects appear in court in murder of innocent Bronx teen',
#  'Ivanka Trump&apos;s associates baffled by her silence on border',
#  'Five-metre great white shark spotted off Majorca in first confirmed sighting in decades',
#  'The Best Cars For 2018',
#  'Explainer: What will it cost to denuclearize North Korea?',
#  'Myanmar transit camps sit empty as Rohingya fear return',
#  'The Last Aircraft Carrier Showdown: Welcome to the Battle of the Philippine Sea',
#  'The Deadliest Day For U.S. Journalism Since 9/11',
#  'Donald Trump Responds To Annapolis Shooting',
#  'Judge: Colorado Walmart triple killing case will go to trial',
#  'Here&apos;s What Could Happen to Roe v. Wade and Abortion Rights After Justice Kennedy&apos;s Retirement',
#  'Nissan GT-R50 by Italdesign: Gallery',
#  'School Bus Overturns on Jersey Turnpike',
#  'Dodgers&#39; Hernandez to fund house building in Puerto Rico',
#  'Eight south Syria towns return to regime control under deals: monitor',
#  '3 Men Sentenced for Killing Chicago Teen in Front of His Twin Brother',
#  'How major US stock indexes fared Friday',
#  'Obama Chides GOP Values: &apos;A Fundamental Contrast Of How We View The World&apos;',
#  'The Latest: Hundreds attend vigil for slain paper staffers',
#  'How the B-1B Bomber Could Be Transformed into a Navy Killer',
#  'Mother, 100, meets daughter, 79, for the first time in emotional reunion',
#  'Is Ford Going To Offer A Toothless Fiesta ST?',
#  'Israel will not accept any Syrian refugees on its territory: defense minister',
#  'Health, leadership questions about Boko Haram&#39;s Shekau',
#  'Man causes $500,000 worth of damage driving through San Angelo Walmart',
#  'Fuel Economy and Driving Range',
#  'Montgomery Coroner: Paint Creek firefighter&apos;s death caused by blunt force trauma to head',
#  'Chillicothe residents key to uncovering history of Thomas Jefferson&apos;s Monticello',
#  'Love fireworks? Here&apos;s how to see multiple fireworks shows next week',
#  'Natural gas work impacts city paving plans, streets around new schools',
#  'Why we prostitute: Local women open up about their struggles, recovery',
#  'Ross County mosquito trap tests positive for West Nile',
#  'ELECTION 2018: Betty Sutton continues ECOT offensive in Chillicothe stop',
#  'Chillicothe school board has mixed reaction to Tiffin principal&apos;s resignation',
#  'New live country music venue takes root in Frankfort',
#  'Fire community, loved ones give final goodbyes to Ross County firefighter',
#  'Lawhorn shares his journey',
#  'Why we prostitute: Tara Pettit',
#  'Rally for Jason &ldquo;Boog&rdquo; Bartley',
#  'Newlyweds raise barn, events business from scratch',
#  'Hundreds gather to honor fallen firefighter',
#  'Fallen firefighter honored by hundreds at funeral',
#  'Ross County grand jury indictments include trespass, thefts',
#  'Change of venue denied for man accused of dumping teen Jason &apos;Boog&apos; Bartley&apos;s body',
#  'Police seek suspect breaking into cars on Winona, Maplewood',
#  'Chillicothe municipal court disposition records',
#  'Who is the man behind Chillicothe&apos;s upcoming medical marijuana dispensary?',
#  'Efforts ongoing to limit local Hepatitis A spread',
#  'NEWS BRIEFS: Frankfort announces July 4 event',
#  'Employers encouraged to decide medical marijuana policy now',
#  'Chillicothe and Ross County public records: Crime reports',
#  'Want BrewDog to build a pub in Lancaster? Grab 499 of your friends and get your wallet',
#  'Public records: Crime reports for June 22-25',
#  'Public records: Crime reports for June 26',
#  'Return of city recycling program boosted by grant, OUC partnership',
#  'NEWS BRIEFS: Piketon cleanup funding in spending bill',
#  'Sheriff&apos;s office warns of suspicious calls',
#  'Public Records: Common Pleas Court',
#  'Ross County Horseshoe Club raising money for indoor facility',
#  'Ross County man who died in firehouse accident mourned by local firefighters',
#  'South Salem woman killed in motorcycle crash on Lower Twin Road',
#  'Public Records: Restaurant Inspections for June 25',
#  'NEWS BRIEFS: Lawhorn reaches Maryland finish line',
#  'City schools to take step toward second levy try',
#  'Baseball: West Virginia Miners 1, Chillicothe Paints 0',
#  'United Way&apos;s Map Your Future program teaches real life lessons',
#  'Praising the Lord with a Western theme',
#  'Aesop&apos;s Tables Fundraiser',
#  'Pioneer students can at Camp Can Do',
#  'The Ross County ADvertiser',
#  'Ross County real estate sales database',
#  'Cincinnatians take part in local &apos;Families Belong Together&apos; march',
#  'Police: Man shot in the leg in West Price Hill; suspect on the run',
#  'PX column: I&apos;m not your enemy. Let&apos;s hope Trump tones down attacks on media after shooting',
#  'Covington OKs concept plan for former Gateway site',
#  'Daniel Greis found guilty of murder of Pollitt family: &apos;There are no winners in this case&apos;',
#  'Federal judge rejects Ky. rules requiring Medicaid recipients to work',
#  'Protesters rally along Fifth Street in reaction to SCOTUS vote for Trump&apos;s travel ban',
#  'Amelia resident removed from council meeting in handcuffs',
#  '3 headlines: Drake&apos;s Cincy trips, Kings Island&apos;s greatest export and new Moerlein beer',
#  'Joe Biden in Cincinnati: President Trump&apos;s only ideology is &apos;aggrandizing power&apos;',
#  '&apos;Stop hangin out&apos;: Cincinnati Dunkin&apos; Donuts fires employee for message on homeless woman&apos;s cup',
#  'Joe Biden: "This is a battle for the soul of America"',
#  'Teen critically injured in I-275 crash near Fort Wright',
#  'Joe Biden, former Vice President, visits local barber',
#  'Newport thrift store closed, but St. Vincent de Paul presence remains',
#  'Joe Biden grilled by reporter&apos;s grandmother on flight to Cincy',
#  'Joe Biden on flight to Cincinnati',
#  'Northern Kentucky University: New president Ashish Vaidya likes NKU&apos;s &apos;nimbleness&apos;',
#  'Hamilton Schools staff can be armed',
#  'Judge disagrees with parents, doctors. Says transgender teen needs to &apos;Age. Develop. Mature&apos;',
#  'No clemency for killer who picked up victim at Cincinnati bar, Gov. John Kasich says',
#  'Magistrate grants county permanent custody of girl who lost parents to heroin',
#  'The day WCPO was taken over by an armed man',
#  'Moerlein to debut blueberry wheat ale to honor the Banks',
#  'Settlement includes plan to stop overcrowding emergencies at the Hamilton County jail',
#  'Defense says Greis showed indifference to life in closing statements',
#  'Ohio security shouldn&apos;t have stopped black, female lawmaker, complaint says',
#  '&apos;Pastor Protection Act&apos; passed by the Ohio House',
#  'Miniature horse found near Owensville; rescuers looking for the owner',
#  'When he was arrested for murder, the 16-year-old&apos;s parents were nowhere to be found.',
#  'Small Confederate monument now displayed on private land',
#  'This week in junk food: A &apos;cheezy&apos; return, a twist on fries, and spiced up chips',
#  'Sunday is National Blue Ice Cream Day',
#  'Hamilton County Commissioner Chris Monzel:  &apos;Personal decision&apos; not to sign gay pride proclamation',
#  'Reports: Chipotle-backed Pizzeria Locale closing both Cincinnati locations, others nationwide',
#  'Here&apos;s how to snag free Baskin-Robbins in July, starting Sunday',
#  'Setting off fireworks this weekend? Friday and Saturday are best weather bets',
#  'Feds: Hamilton clinic gave pain drugs, &apos;Prescriptive Speedball&apos; without seeing patients',
#  'Developers reveal plans for $2 billion entertainment park',
#  'Convergys being sold to California company',
#  '83-year-old veteran bought house for grandson, who struggled with drugs: &apos;I was scammed&apos;',
#  '&apos;If you think Trump&apos;s got it bad...&apos; Deer Park Councilman reprimanded for personal attacks: says move meant to humiliate',
#  'GALLERY: 15 of our favorite Coney Island Balloon Glow photos',
#  'A NKY Fourth of July: Where to watch fireworks and parades',
#  'What steps can you take to protect your child from a would-be abductor',
#  'Westwood &apos;reimagined&apos;: City officials break ground on Madcap development',
#  'Zoombezi Bay Summer Nights debuts June 29',
#  'How to help Capital Gazette journalists after the Annapolis newsroom shooting',
#  'Former Muskingum University student convicted of killing her own baby gets new hearing',
#  'Kids learn how to take a bite out of crime',
#  'Community News and Notes',
#  'Coshocton Senior Center July Events',
#  'Crime Reports: Public Records',
#  'As history happened, Annin flags were there',
#  'Lori Henry appeals human trafficking conviction',
#  'Heritage Vineyard named top winery destination',
#  'Community News and Notes',
#  'Crime Reports: Public Records',
#  'Lafayette Township Trustees having meetings',
#  'Tribune not publishing on holiday',
#  'Warning siren test moved to July 11',
#  'Remembering the sacrifices: Collections from WWII veterans',
#  'Crime Reports: Public Reports',
#  'Community News and Notes',
#  'Birthday wish fulfilled by sheriff&apos;s office',
#  'Teen&apos;s social media post taunted officers, led to apprehension',
#  'Small tattoo has a big impact',
#  'Guernsey County reports hepatitis A case in wake of outbreak',
#  'New hours for the library system',
#  'Bedford Township Trustees to meet',
#  'Community News and Notes',
#  'Safety City imparts valuable lessons to youth',
#  'A week of celebrations, from ice cream sodas to Korean War',
#  'New device aids Bob Newcomer in his fight against cancer',
#  'Looking at ER care through a patient&apos;s eyes',
#  'Ohio declares statewide outbreak of hepatitis A',
#  'A look at what you can recycle and where in Coshocton County',
#  'Love is love, with no boundaries or restrictions',
#  'What you need to know about poison hemlock',
#  'Louisville and Churchill Downs were sure bets',
#  'Coshocton County Real Estate Transfers',
#  'River View BOE notes',
#  'Community News and Notes',
#  'Copper Horse Crusade continues to grow',
#  'Camp Invention focused on creative problem solving',
#  'Coshocton Hot Air Balloon Festival 2018',
#  'State Track 2018 Day 2',
#  'State Track 2018, Day 1',
#  'Coshocton Memorial Day festivities',
#  'Otter Banks opens Saturday at Zoombezi Bay',
#  'The Coshocton County ADvertiser',
#  'Coshocton County property transfers',
#  '2-vehicle crash closes eastbound lane on U.S. 20',
#  'After decades of debate, Ballville Dam demolition will start next week',
#  'Terra State dorm contractor agrees to pay for any shortfalls',
#  'Here are the top stories in The News-Messenger in June',
#  'Sex offender investigated for allegedly running home daycare center',
#  'Religion Briefs',
#  'Pastor Wilson tapped to develop relationship with community',
#  'Saturday Briefs',
#  'As history happened, Annin flags were there',
#  'Changes in migrant Head Start program leave farmers scrambling',
#  'Officials sweat it out to demonstrate dangers of heat',
#  'Inside a car on a hot day',
#  'Reineke shifts gears, backs existing wind turbine setback law turbines',
#  'Friday Briefs',
#  'Rachel Cruze: How to go on vacation without going into debt',
#  '2 men drown in unrelated incidents on Lake Erie',
#  'Medicaid treatment for opioid addiction soars locally, statewide',
#  'Terra dorm may not be ready for start of semester',
#  'Fremont man sentenced to 16 years in rape case',
#  'Thursday briefs',
#  'NRC sheds light on Davis-Besse decommissioning process',
#  'Put-in-Bay boater found dead identified as Michigan man',
#  'Sen. Sherrod Brown touts bill helping grandparents raising children due to opioid crisis',
#  'Australian Lottery scam comes down under to Sandusky County',
#  'No need to wait until July 4 to celebrate Independence Day',
#  'History Spotlight: St. Joseph&apos;s School',
#  'Talk About Oak Harbor:  Cake pops are bakery&apos;s signature treat',
#  '&apos;Dreamland&apos; author Sam Quinones says community is antidote to opioid crisis',
#  'Kroger downsizing plans for new Fremont store',
#  'Steve Arndt pushing new legislation to help Davis-Besse Power Station',
#  'Community Roundup',
#  'Wednesday Briefs',
#  'Learning to &apos;Just Listen for Justice&apos;',
#  'Damschroder column: When two out of three is bad',
#  'Soggy weather doesn&apos;t stop GroveFest',
#  'Appeals court reverses Fremont man&apos;s conviction',
#  'O&apos;Connell attorney seeks to have 3 charges dropped',
#  'GroveFest at Spiegel Grove',
#  'Special Olympic torch run',
#  'Downtown Fremont Farmers Market',
#  'N.O.V.F.A. parade in Gibsonburg',
#  'Relay for Life at Conner Park',
#  'Sandusky County property transfers',
#  'Gasoline prices in Sandusky County',
#  '&apos;Operation Crystal Clear&apos; aims to clean up meth trade in Fairfield County',
#  'Police seek driver possibly involved in Ohio 158 crash',
#  'Survivor describes impact of sexual assault by Lancaster piano teacher',
#  'Former city drinking water analyst avoids jail after admitting to falsifying data',
#  'Probation violation warrant leads to fatal hit and run suspect&apos;s arrest',
#  'With more people shopping from home, can the River Valley Mall survive?',
#  'Ghost hunting group investigates Miller Building',
#  'Business planning to hire prison inmates denied zoning variance by city board',
#  'Kinsler | The creation of modern life',
#  '&apos;Worst intersection&apos; in Fairfield County to get makeover before new junior high arrives',
#  'John Glenn Astronomy Park opens at Hocking Hills',
#  'Saturday storm damaged Pleasant Township barn roof',
#  'Mother chooses life for disabled child',
#  'Lancaster photographer&apos;s inspiring &apos;Warrior Queen&apos; images of girl with no legs go viral',
#  'Inspiring &apos;Warrior Queen&apos; images of girl with no legs go viral',
#  'Fairfield County municipal court disposition records',
#  'Eagle-Gazette reporter plays original piece with orchestra',
#  'Sheriff&apos;s office investigates &apos;suspicious letter&apos; delivered to judge&apos;s office',
#  '"Suspicious letter" to judge&apos;s office draws investigation',
#  'Turban Project boosts spirits of cancer patients, celebrates sixth year',
#  'Want BrewDog to build a pub in Lancaster? Grab 499 of your friends and get your wallet',
#  'NEWS BRIEFS: Forest Rose plans meeting; businesses announce awards, promotions',
#  'OSU Extension: Marestail ... a nasty weed to control',
#  'Conservation Corner: Another Earth Camp in the books',
#  'If you want to see multiple fireworks displays, here&apos;s your Fairfield County list',
#  'No injuries reported in fire at TreeHouse Foods plant',
#  'Canal Winchester news: Two free Movie in the Park events upcoming',
#  'Bloom-Carroll area news: Shane Roush Memorial Golf Tournament set for July 8',
#  'Millersport news: No Buckeye Lake BLASST this year',
#  'NEWS BRIEFS: Fairfield County 2-1-1 board names new executive director',
#  'Baltimore news: Food pantry recovers from power surge that damaged refrigeration units',
#  'Public Records: Restaurant Inspections for June 25',
#  'PUBLIC RECORDS: Marriage Applications, Divorce and Dissolution for June 24',
#  'College, school and community notes for June 24',
#  'Remember When: Forgotten chapter in history of Keller Block',
#  'Ohio declares statewide outbreak of hepatitis A',
#  'Great Ohio Bicycle Adventure tours Fairfield County',
#  'Day of Action draws hundreds downtown to play',
#  'Bremen church uses cooking, art to reach community children',
#  'Storm damages 100-year-old barn in Pleasant Township',
#  'State Track 2018 Day 2',
#  'The Lancaster-Fairfield ADvertiser',
#  'Fairfield County real estate sales database',
#  'Ashland BalloonFest pilot dies Friday night',
#  'Ashland&apos;s 28th annual BalloonFest lifts off',
#  'Liberty Pool will not open as scheduled because of pump issue',
#  'Mary Anne&rsquo;s Meats re-opening on July 31',
#  'Mansfielder Chris Hahn&apos;s episode of &apos;The Proposal&apos; will air on July 9',
#  'Former garage transformed into spacious guest house near Mansfield',
#  'Felony court sentencings for July 1, 2018',
#  'Madison school board approves raising elementary student fees',
#  'Man tells police woman stabbed him in the chest',
#  'Demolition of old YMCA, Buckingham Street church planned later this summer',
#  '72 years after graduation, Mansfield Senior classmates meet monthly',
#  'After heated school board meeting, Madison school district plans public forums',
#  'Police Calls | Man shot in leg on Vale Avenue Thursday night',
#  'As history happened, Annin flags were there',
#  '188 fake Oxycodone pills suspected of containing fentanyl found during METRICH raids',
#  'Mansfield building and codes manager J.R. Rice retiring, returning to IBEW',
#  'North Central State College to offer IT support professional certificate',
#  'Lexington schools: Committee recommends November bond issue',
#  'Police Calls | Pharmacy gets fraudulent prescription',
#  'Hydroplaning suspected in Bowman Street Road crash that injured three',
#  'Mansfield Municipal Court sentences',
#  'Heat stroke a concern in North Central Ohio as temperatures rise this weekend',
#  'West Nile virus detected in Mifflin Township mosquitoes',
#  'Police Calls | Suspects put jelly, barbecue sauce and applesauce on vehicles',
#  'Commissioners to view proposed Niss Waterfall Preserve property',
#  'Madison parents express frustration with district leaders at school board meeting',
#  'Crawford County teachers to be trained in disaster preparedness',
#  'BalloonFest floating into Ashland for 28th year of summer fun',
#  'When are this year&apos;s Mansfield area Fourth of July fireworks?',
#  'Medicaid spending on opioid treatment soars in Ohio, auditor reports',
#  'Shelby police officers who shot Tiro man acted in self-defense: grand jury',
#  'Car veers off U.S. 30, strikes semi cab',
#  'Butler County man who had AR-15 in vehicle after threatening court officials gets 18 months',
#  'Ashland man Life-Flighted after three-vehicle Ashland County crash on U.S. 30',
#  'Safety Town graduation',
#  'Duck family reunited',
#  'Grate house demolished',
#  'Photos: Miss Ohio Parade 2018',
#  'State Track 2018 Day 2',
#  'Mansfield-area property transfers',
#  'Gasoline prices in Mansfield area',
#  'What to know about the Marion County fair',
#  'Convicted drug dealer indicted for drug possession',
#  'As history happened, Annin flags were there',
#  'Marion County has one of highest rates of addicted Medicaid recipients',
#  'What you need to know about Marion&apos;s upcoming medical marijuana dispensary, its owner',
#  'Voter information for the Aug. 7 special election',
#  'New Marion County coroner named, receives a &apos;baptism&apos; by fire',
#  'Marion Public Health cited these places for critical violations, June 19-25',
#  '5 ways to celebrate 4th of July near Marion',
#  'Heat stroke a concern in North Central Ohio as temperatures rise this weekend',
#  'Ed McCants, local basketball star, plans to launch bid for mayor of Marion',
#  'Marion County residents question ditch project cost',
#  'Marion law enforcement tells candidate to improve drug testing',
#  'Shelby police officers who shot Tiro man acted in self-defense: grand jury',
#  'Marion man&apos;s defense might blame gun for shooting of girlfriend',
#  'Briefs: Satch Sullinger coming to WWGH',
#  'Vaccinations urged in wake of hepatitis A outbreak in Ohio',
#  'Four people, including two children, injured in crash outside Marion',
#  'Children&apos;s museum could find home in Carnegie building',
#  'Potential trade war worries Marion farmers',
#  'Local balloon artist pops onto scene',
#  'Ohio declares statewide outbreak of hepatitis A',
#  'Marion County property transfers for week of June 6',
#  '2018 Law enforcement torch run',
#  'Police beat: Identity theft reported on Park Boulevard',
#  'What items should be on Marion County&apos;s bucket list?',
#  'Police beat: Assault reported at Sprint store on Marion-Mount Gilead Road',
#  'Public Records: Restaurant inspections, June 14-18',
#  'Marion initially "overwhelmed" with tall grass complaints',
#  'Nye Street house catches fire overnight, no one injured',
#  'United Way meets about 75 percent of donations goal',
#  'Former Waldo Pool manager pleads guilty to stealing money from pool',
#  'Johnsville 4-year-old OK after getting stuck in pipe',
#  'Marion Family Y offering youth summer camps',
#  'Marion loft tour summer 2018',
#  'Marion Pleasant 2018 Graduation',
#  'State Track 2018 Day 2',
#  'State Track 2018, Day 1',
#  'River Valley Graduation 2018',
#  'Marion County property transfers',
#  'Gasoline prices in Marion County',
#  'CEO Profile &ndash; Jim Johnson, Hopewell Federal',
#  'Brady: Blue skies ahead for Buckeye Lake',
#  'Dager: Buckeye Lake just one of region&rsquo;s many draws',
#  'Dager: Buy local more than a slogan',
#  'Arnold: Opportunities in retail and dining abound for young, local entrepreneurs',
#  'Successful downtown businesses help one another succeed',
#  'Strum: We must invest ourselves locally',
#  'Licking County to take advantage of western growth',
#  'Arnold: Young professionals face unique tax issues',
#  'McDonald: Tax changes should benefit local economy',
#  'Pataskala chamber addresses tax changes',
#  'Dager: Tax changes expected to benefit Licking County employees, businesses',
#  'STEM profile: Margaret Spoo-Chupka',
#  'PNB: I&rsquo;ve decided I need a trust. Now what?',
#  'Local companies hopeful about tax cuts, but delay bonuses',
#  'Platt: Our Economy Benefiting From Natural Gas Industry',
#  'Millennials: 1 in 6 have $100,000 in savings',
#  'Rehbeck: There are many reasons to consider a trust',
#  'Amazon set to open its grocery store without a checkout line to the public',
#  'Arnold: New calendar offers young leader new opportunities',
#  'Dager: Tourism should be on next governor&rsquo;s to-do list',
#  'McDonald: A look back and ahead',
#  'Rine: Workforce opportunities for local businesses',
#  'Schaller, Campbell, Untied add attorney',
#  'Cecil Mauger Trust announces online grant application',
#  'Licking Memorial hires internal medicine physician',
#  'Local attorney joins juvenile detention district board',
#  'Hospice of Central Ohio seeks volunteers',
#  'Hopewell Federal to award scholarship',
#  'Hopewell Federal donates to American Red Cross',
#  'OSU Newark professor does research at The Wilds, for ODOT',
#  'Mills: A Financial Christmas Carol',
#  'Dager: 2017 Bellwether For Busy Year Ahead',
#  'Edelblute: 2017 an exciting year for Pataskala',
#  'The Advocate&apos;s 20 Under 40 2016',
#  'Chamber of Commerce 13th Annual Dinner & Awards Celebration',
#  'Inside the new Amazon center',
#  '2015 Advocate 20 Under 40',
#  'Longaberger looks to the future',
#  'Licking County Proud',
#  'The Newark-Licking ADvertiser',
#  'ODNR identifies 3rd drowning victim as visitor from India',
#  '&apos;Greetings from Port Clinton&apos;: New mural welcomes Art Walk patrons',
#  'Sex offender investigated for allegedly running home daycare center',
#  'Here are the top stories in the News Herald for June',
#  'As history happened, Annin flags were there',
#  'Art Walk downtown Port Clinton',
#  '2 men drown in unrelated incidents on Lake Erie',
#  '&apos;Historic&apos; flooding spurs Port Clinton to look at infrastructure',
#  '&apos;Dreamland&apos; author Sam Quinones speaks at Lakeside',
#  'NRC sheds light on Davis-Besse decommissioning process',
#  'Put-in-Bay boater found dead identified as Michigan man',
#  'Sen. Sherrod Brown touts bill helping grandparents raising children due to opioid crisis',
#  '&apos;Dreamland&apos; author Sam Quinones says community is antidote to opioid crisis',
#  'Steve Arndt pushing new legislation to help Davis-Besse Power Station',
#  'Learning to &apos;Just Listen for Justice&apos;',
#  'Property Transfers',
#  'Hepatitis A outbreak reaches Sandusky, Ottawa counties',
#  'Labatt Blue&apos;s &apos;Loving Ohio&apos; campaign promotes Lake Erie',
#  'Boy Scouts build gaga ball pit for Oak Harbor Middle School',
#  'New museum showcases Catawba&apos;s rich history',
#  'Ohio declares statewide outbreak of hepatitis A',
#  'Boater&apos;s body pulled from water at Put-in-Bay',
#  'Man pleads guilty to attempted rape of 14-year-old girl',
#  'Put-in-Bay police chief now wearing just one hat',
#  'Genoa police: Stolen guns, chainsaws, 2 missing juveniles found after traffic stop',
#  'Giraffe calf dies at birth at Monsoon Lagoon Park',
#  'Kids dive into wetlands wildlife at &apos;Aqua Adventure&apos; camp',
#  'Kids dive into wetlands wildlife at &apos;Aqua Adventure&apos; camp',
#  'Magruder pharmacy robbery suspect found competent to stand trial',
#  'Reconstruction of the Port Clinton Lift Bridge',
#  'Inside the Port Clinton Lift Bridge',
#  'Lift Bridge to miss July 4 reopening date',
#  'Catawba Museum at Union Chapel opens',
#  'Volunteers help neighbors after Ottawa County flooding',
#  'Property Transfers',
#  'DNA evidence debated by attorneys in Heather Bogle murder case',
#  'Hoover Auditorium brought historic speakers to Lakeside',
#  'Relay for Life at fairgrounds',
#  'Veterans memorial dedication',
#  '2018 Port Clinton Middle School Talent Show',
#  'Immaculate Conception School celebrates &apos;WOW Day&apos;',
#  'Port Clinton High School Graduation 2018',
#  'Ottawa County property transfers',
#  'Gasoline prices in Ottawa County',
#  'Muskingum Library seeking an increased levy',
#  'Sheridan High School academic rolls',
#  'Ohio University Zanesville Notes',
#  'Muskingum County Marriage Licenses Issued',
#  'Tyler Herron&apos;s memory still strong at John Glenn',
#  'Fighting the enemy within',
#  'Former Muskingum University student convicted of killing her own baby gets new hearing',
#  'Court Record',
#  'Community News and Notes',
#  'Former Philo student sentenced in knife incident',
#  'Drug search demonstration',
#  'As history happened, Annin flags were there',
#  'Muskingum County Real Estate Transfers',
#  'Part of Main Street closed by water department',
#  'Local farm bureau receives grant',
#  'South Zanesville Council to meet',
#  'Part of I-70 restricted for slide repair',
#  'North River Road closing for work',
#  'Annin Flag Company',
#  'Lori Henry appeals human trafficking conviction',
#  'With its first album in 20 years, Shenandoah&apos;s tour making Zanesville stop',
#  'Community News and Notes',
#  'As overdoses spike, South Zanesville gets its first ambulance in 20 years',
#  'Franklin Schools having BOE meeting',
#  'Perry County County Board of DD to meet',
#  'Roseville Council cancels regular meeting',
#  'Schools having special meetings Friday',
#  'Sanitation services running on time next week',
#  'Community News and Notes',
#  'Remembering the sacrifices: Collections from WWII veterans',
#  'Cutler Lake Dam improvements to be completed by end of year',
#  'Cutler Lake Dam construction underway',
#  'Birthday wish fulfilled by sheriff&apos;s office',
#  'Zanesville man facing 40 years in West Virginia prison',
#  'Copper Horse Crusade',
#  'Special Olympic torch run',
#  'Ohio Flags of Honor come to Zanesville',
#  'State Track 2018 Day 2',
#  'State Track 2018, Day 1',
#  'The Zanesville-Muskingum ADvertiser',
#  'Muskingum County property transfers',
#  'Documents show value of recreation at Cascade-Siskiyou National Monument',
#  'As labor contract is soon to expire, City of Salem employees seek more money',
#  'Keep Families Together rally near Oregon State Capitol on June 30',
#  'How an Oregon mega dairy is tapping an off-limits aquifer',
#  'VIDEO: Salem/Keizer&apos;s top 10  most dangerous intersections',
#  'WATCH: Demolition begins for new Salem Police headquarters',
#  'VIDEO: Salem-Keizer students join national walkouts',
#  'No charges for Marion County deputy caught on video punching homeless person 17 times',
#  'New on July 1: Minimum wage increase, transportation tax, education laws',
#  'Week in Review: June 25-29',
#  'Man accused of killing mom, 4 kids in car crash rejects plea deal, heads to trial',
#  'Here are the new stores and restaurants at Willamette Town Center',
#  'Oregon will require drinking water systems to test for algal toxins',
#  'Updated June 29: Full test results of Salem&apos;s drinking water',
#  'Salem water crisis: Successful tests as full-scale carbon treatment nears',
#  'Chetco Bar Fire area approved for salvage logging by U.S. Forest Service',
#  'Beavers win third national championship',
#  'Salem water crisis: Detroit Lake hit with 4th toxic algae advisory',
#  'A look at Salem&apos;s retail scene',
#  'Salem water crisis: Looking for solutions',
#  'Wildfire Prevention: Keeping your home safe',
#  'Salem man convicted of  first-degree rape, sex abuse gets 14 years in prison',
#  'Dog with biting history mauls Silverton girl, tearing through her leg and exposing bone',
#  'Benson Bridge reopens at Multnomah Falls after Eagle Creek Fire',
#  'Incarcerated youth honored at MacLaren graduation',
#  'Dayton woman killed in two-vehicle crash on Highway 221',
#  'Wineries hedge against climate change, move to cool climates',
#  '8 arrests as federal police clear entrance to Portland ICE building',
#  'How to avoid dog bites',
#  'Supreme Court&apos;s public employee union ruling could stifle Oregon membership',
#  'Public viewing set for owner of Kwan&apos;s restaurant',
#  'Snapshots from Salem couple&apos;s Airstream world travels in 1963-64',
#  'New sculpture installed at Salem Convention Center',
#  'Wildfire season begins in Oregon',
#  'Vintage Airstreams join international rally in Salem',
#  'Graham Fire prompts evacuations near Lake Billy Chinook in C. Oregon',
#  'Corrections & clarifications',
#  'DOJ: Maryland man indicted for Blue Ridge Summit bank robbery',
#  'Franklin Co. commissioners buy another property for courthouse project',
#  'Watch: Here are the headlines to know today',
#  'It is strawberry season at The Drying Shed',
#  'Woman Thanks Citizens for Stopping Alleged Purse Snatcher (1)',
#  'Black World War II veteran finally saluted as officer after 76 years',
#  'Newburg woman among 15 charged with Medicaid fraud in Pa.',
#  'Cooling off at Shippensburg Memorial Park Pool',
#  'Comcast outages spread nationwide; if your Internet was wonky, you were not alone',
#  'Gravel lot near busy Walker Road intersection could soon host a Hilton hotel',
#  'Update: Police identify suspects in theft of air conditioners from Waynesboro Hospital',
#  'Promising to cut cost and time in half, new express bus goes to NYC from York, Lancaster',
#  'Police log: Boy, 8, and two others go to hospital after rollover crash in Letterkenny Twp.',
#  'Summit Health and Wellspan Health sign affiliation agreement',
#  'Fireworks can be dangerous for pets. Here&apos;s how to keep them safe this 4th of July',
#  'Pennsylvania clergy abuse: Attorney General Shapiro fights to release grand jury report',
#  'Butcher Shoppe opening another micro market: Find out where',
#  'Chambersburg police: Scammer pretends to be a soldier trying to avoid assignment to Syria',
#  'People all over the world use products made right here in Franklin County',
#  'Gov. Tom Wolf, who has pushed for higher minimum wage, raises it for government workers',
#  'Immigration debate: Look for white shirts and protest signs in 22 Pa. cities Saturday',
#  'Crank that A/C! It will feel like it&apos;s 100 degrees or more for days in Franklin County',
#  'Teacher charged with sexual abuse of 5 elementary school students',
#  'Chambersburg police seek suspects, motives behind shooting at Southgate',
#  'Man accused of exposing himself to daycare, police say',
#  'Chambersburg man held on charges of false imprisonment',
#  'Pennsylvania judge on Trump&apos;s Supreme Court nominee list as Anthony Kennedy retires',
#  'Employment at all-time high in Franklin County',
#  'Chambersburg man to serve federal time for fentanyl pill operation',
#  'Photos: York County bikers gather for weekly bike night',
#  'Photos: Vintage movie theaters in Central Pennsylvania. Are you a fan?',
#  'Toys R Us through the years',
#  'Photos: Not in compliance with Megan&apos;s law June 18',
#  'Photos: People enjoy tailgate before Zac Brown Band concert',
#  'How to help Capital Gazette journalists after the Annapolis newsroom shooting',
#  'Terrifying stories from tourists in Mexico continue a year after mysterious drowning',
#  'Black World War II veteran finally saluted as officer after 76 years',
#  'Bolton announces candidacy for Adams County commissioner (letter)',
#  'Comcast outages spread nationwide; if your Internet was wonky, you were not alone',
#  '&apos;Welcome to the table&apos;: Celebrating Unity, York sets goal for 10,000 Acts of Kindness',
#  'There&apos;s a really easy way you can help Bermudian Springs win a national cheerleading contest',
#  'Photos: Kicking off 10,000 Acts of Kindness for York County',
#  'Delone Catholic graduate Kayla Repasky crowned Miss Pennsylvania',
#  'Bermudian Springs: School spirit has no offseason',
#  'Promising to cut cost and time in half, new express bus goes to NYC from York, Lancaster',
#  'Police log: Peacock spotted again in Penn Township',
#  'Student-athletes find other ways to college sports',
#  'NASCAR&apos;s Kasey Kahne returns to Lincoln Speedway',
#  'Spring Grove triple jumper striving for states',
#  'Hanover Elite Cheer uses family focus to build success',
#  'Fireworks can be dangerous for pets. Here&apos;s how to keep them safe this 4th of July',
#  'Pennsylvania clergy abuse: Attorney General Shapiro fights to release grand jury report',
#  'Photos: 15 restaurants we miss from Central Pa&apos;s past',
#  'Gov. Tom Wolf, who has pushed for higher minimum wage, raises it for government workers',
#  'Immigration debate: Look for white shirts and protest signs in 22 Pa. cities Saturday',
#  'Photos: Tropical Storm Agnes&apos; late June flooding - other York deluges',
#  'Photos: These York County mystery steps lead to somewhere. But where?',
#  'Maryland man indicted for Carroll Valley armed bank robbery',
#  'Teacher charged with sexual abuse of 5 elementary school students',
#  '&apos;I&apos;m really happy I can be a United States citizen today&apos;',
#  'DOJ: Maryland man indicted for Blue Ridge Summit bank robbery',
#  'West Manheim police chief to retire after 30 plus years of service',
#  'Photos: Check out the newest US citizens in York County',
#  'Photos: Carroll County, Maryland, Most Wanted list',
#  'Photos: The Civil War comes to York County, Pa.',
#  'Photos: York County bikers gather for weekly bike night',
#  'Photos: These York County buildings were jacked up and moved',
#  '&apos;No words to explain the feeling&apos; as 47 become naturalized citizens in York County',
#  'Police: Man charged with rape after he assaulted two girls during a nine-year span',
#  'Pennsylvania judge on Trump&apos;s Supreme Court nominee list as Anthony Kennedy retires',
#  'How to help Capital Gazette journalists after the Annapolis newsroom shooting',
#  'Terrifying stories from tourists in Mexico continue a year after mysterious drowning',
#  'Police log: Peacock found on a roof in Penn Township',
#  'This is how many migrant children are staying in Pennsylvania',
#  'These are the most wanted people in Carroll County, Maryland',
#  'News Now: Spring Grove grad signs with Orioles',
#  'Black World War II veteran finally saluted as officer after 76 years',
#  'Vehicles crash on Kochenderfer Road curve',
#  'Heat advisory, air quality alert issued for Lebanon',
#  'Comcast outages spread nationwide; if your Internet was wonky, you were not alone',
#  'Daily Dose: U.S. soccer star Christian Pulisic treats hometown kids to clinic in Hershey',
#  'Daily Dose: Soccer star Pulisic returns to his native Hershey',
#  'Lebanon man points firearm at four individuals, police say',
#  'Promising to cut cost and time in half, new express bus goes to NYC from York, Lancaster',
#  'Area elementary teacher charged for sexually assaulting 5 students',
#  'Fireworks can be dangerous for pets. Here&apos;s how to keep them safe this 4th of July',
#  'Pennsylvania clergy abuse: Attorney General Shapiro fights to release grand jury report',
#  'Self-driving robots captivate Lebanon kids at Camp Invention',
#  'Self-driving robots captivate Lebanon kids at Camp Invention',
#  'Self-driving robots captivate Lebanon kids at Camp Invention',
#  'Two vehicles towed after North Lebanon crash',
#  'Gov. Tom Wolf, who has pushed for higher minimum wage, raises it for government workers',
#  'Immigration debate: Look for white shirts and protest signs in 22 Pa. cities Saturday',
#  'American Pickers television show coming to Pennsylvania',
#  'Free lunches available for Lebanon youths',
#  'New details on Rutter&rsquo;s coming to West Lebanon',
#  'Police officer&apos;s Taser use &apos;of great concern,&apos; Lancaster mayor says',
#  'Teacher charged with sexual abuse of 5 elementary school students',
#  'Pennsylvania judge on Trump&apos;s Supreme Court nominee list as Anthony Kennedy retires',
#  'Lebanon area: A heat wave is on the way',
#  'Local watershed groups seek $2.9 million in Sunoco penalty grants',
#  'This is how many migrant children are staying in Pennsylvania',
#  'Palmyra police seek hit-and-run driver',
#  'The Star Barn has been moved, preserved and reconstructed into a modern venue',
#  'Top-notch BBQ: These are the best barbecue joints in central Pa.',
#  '7 things to do this weekend in Lebanon County, June 29-July 1',
#  'Channing Tatum hawks vodka in Hummelstown',
#  'Summer concert series uplifts Coleman Park',
#  'Channing Tatum signs autographs in Hummelstown, Pa.',
#  'What do York County bikers think about President Trump&apos;s reaction to Harley-Davidson?',
#  'Photos: York County bikers gather for weekly bike night',
#  'Crowd of hundreds forms for Channing Tatum in Hummelstown',
#  'Watch Channing Tatum do the robot in Hummelstown, Pa.',
#  'Photos: Vintage movie theaters in Central Pennsylvania. Are you a fan?',
#  'Toys R Us through the years',
#  'Photos: Not in compliance with Megan&apos;s law June 18',
#  'Photos: The reconstructed Star Barn is complete',
#  'Photos: People enjoy tailgate before Zac Brown Band concert',
#  'How to help Capital Gazette journalists after the Annapolis newsroom shooting',
#  'Terrifying stories from tourists in Mexico continue a year after mysterious drowning',
#  'Heroin addiction: Where to get help in Lebanon',
#  'After a PFA, what happens to my gun?',
#  'How safe is your child on the school bus?',
#  'Kortne Stouffer disappearance focus of TV show',
#  '&apos;Welcome to the table&apos;: Celebrating Unity, York sets goal for 10,000 Acts of Kindness',
#  'In 50 states, thousands protest immigration policy, with focus on midterm elections',
#  'Immigration debate: Look for white shirts and protest signs in 22 Pa. cities Saturday',
#  'Where to see fireworks in York County for this 4th of July',
#  'Grilling tips to not burn your house down',
#  'Photos: York County Barbecue Fest',
#  '38GmEkqL0lFRD--8',
#  'Black World War II veteran finally saluted as officer after 76 years',
#  'York Daily Record obituaries for June 30',
#  '&apos;American Pickers&apos; to film new episodes in Pennsylvania this summer',
#  'Fuel headlines Rock at the Park music festival this summer in Lancaster',
#  'GameTimePA announces 2018 YAIAA softball all-stars',
#  'Comcast outages spread nationwide; if your Internet was wonky, you were not alone',
#  'New owner of former Sam and Tony&apos;s site in downtown York is a familiar face',
#  'Penn State recruit &apos;could have died on the field.&apos; He won&apos;t play, but his life was saved',
#  'Yorktowne Hotel: A new name, an upcoming archaeological dig and more',
#  'Colorado mom finally gets to hold baby girl after she was born prematurely at 1 pound',
#  'Lancaster County&apos;s most famous celebrity is...',
#  'Heat wave for a week: Scorching temps to feel like 108 degrees',
#  'Fireworks can be dangerous for pets. Here&apos;s how to keep them safe this 4th of July',
#  'Man faces up to 8 to 16 years for fatal overdose in York County',
#  'Photos: Kicking off 10,000 Acts of Kindness for York County',
#  'Gov. Tom Wolf, who has pushed for higher minimum wage, raises it for government workers',
#  'Police officer&apos;s Taser use &apos;of great concern,&apos; Lancaster mayor says',
#  'Photos: Historic Shady Lane - looking back at this place of beauty',
#  '&apos;These are American bikes.&apos; Harley-Davidson riders weigh in on Trump tariffs',
#  'Nearly 100 complaints prompt York to set up fireworks tip line',
#  'Photos: When Springsteen played York, Pa. Really, he was here.',
#  'Yearlong 10,000 Acts of Kindness kicks off in York',
#  'Plane that crash near Ocean City carried Berlin residents',
#  'Delone Catholic graduate Kayla Repasky crowned Miss Pennsylvania',
#  'Promising to cut cost and time in half, new express bus goes to NYC from York, Lancaster',
#  'Michael Lehman walks free after 30 years in prison: &apos;I thought this day would never come&apos;',
#  'Juvenile lifer Michael Lehman on first day free',
#  'Fat Daddy&apos;s owners lose exclusive option for downtown nightclub site but vow to keep trying',
#  '&apos;I feel like I&apos;m Babe Ruth&apos;: Halfway done, Appalachian Trail hiker fueled by his following',
#  'York County horror novelist faces a horror of his own, suffering severe burns',
#  'Scott Wagner wins Republican nomination for Pa. governor, sets up York County showdown',
#  'Photos: 15 restaurants we miss from Central Pa&apos;s past',
#  'Photos: Tropical Storm Agnes&apos; late June flooding - other York deluges',
#  'Photos: These York County mystery steps lead to somewhere. But where?',
#  'Photos: Check out the newest US citizens in York County',
#  'Photos: Soccer star Christian Pulisic returns to Pennsylvania',
#  'How to help Capital Gazette journalists after the Annapolis newsroom shooting',
#  'Terrifying stories from tourists in Mexico continue a year after mysterious drowning',
#  'Pa. governor&apos;s race 2018: What you need to know about Tom Wolf, Scott Wagner and others',
#  'How much do Pennsylvania educators get paid? Search teacher salaries for 2016-17',
#  'Man shot in Anderson may be victim of botched robbery, police say',
#  'Wreck at high-traffic US29 bypass intersection',
#  'Clemson convenience store death investigated by SLED',
#  'Anderson police investigating shooting at apartment complex; suspect still unknown',
#  'Barnett: More bacteria testing still needed in the Reedy River at Falls Park',
#  'SLED investigating death at 711 in Clemson',
#  'SLED is investigating the death of a man at 711 in Clemson',
#  'SLED investigating death at Clemson convenience store',
#  'Stacy Carmack &apos;potentially overdosed&apos; before her body was burned, authorities say',
#  '&apos;A blessing&apos;: Elderly couple gets full-size refrigerator for the first time in years',
#  'What to do with remaining empty storefronts?',
#  'Refrigerator donation a cool surprise for elderly couple',
#  'Elderly couple receive a refrigerator from AIM and Electrolux',
#  'Chief Stewart talks about shooting at Plez U and Woodland Apartments',
#  'Shooting in Anderson with investigation at Plez U and Woodland Apts',
#  'Anderson police investigating Williamston Road shooting',
#  'Here are 4 hikes in the Upstate to cool you down',
#  'Photos: Memories of Summertime and Fourth of July celebrations',
#  'Part II: The Barnett-Leon plan would fix our immigration problem at its root, not at our border',
#  'Children separated from parents at Mexico border being fostered in South Carolina',
#  'Miss South Carolina 2018 schedule, how to stream live and watch on TV',
#  '3 restaurant franchises have big plans for the Upstate',
#  'Summer showers and summer flowers',
#  'Part I: Fear factors that drive the hysteria over illegal immigration',
#  'Election results for South Carolina&apos;s 2018 primary runoffs',
#  'Lee Bright speaks to supporters',
#  'William Timmons defeats Lee Bright in Republican runoff',
#  'Pickens officer off duty after DUI and child endangerment charges',
#  'Nick Charalambous rides his bike across South Carolina to celebrate cancer recovery',
#  'Celebrating life with Cancer Miracle Tour of SC bike ride',
#  'Lawsuit: Prison guard locked inmate in with violent attackers, was left bleeding for hours',
#  'Santee Cooper asks court to decide if co-ops, customers should pay for nuclear fiasco',
#  'SC Legislature could fail to pass bills fixing VC Summer fiasco',
#  'Don&apos;t be concerned about police activity at Westside High today; training in progress',
#  'Travelers Rest chase reaches triple digits',
#  '2014-15 Peace Center Broadway series preview',
#  'Tajh Boyd says Kelly&apos;s dismissal &apos;disappointing, disheartening&apos;',
#  'You&apos;ll never believe this kidney donation story',
#  'Fire at Hawks Motorsports in Easley',
#  'Foggy morning scenes in Anderson',
#  'Gov. McMaster speaks with Republcan GOP candidates  in Anderson',
#  '2018 GEICO Bassmasters: Championship weigh in',
#  'Local angler Casey Ashley and others kick off 2018 GEICO Bassmasters',
#  'Get breaking news alerts on your phone',
#  'Mother and boyfriend arrested in connection with death of Upstate toddler',
#  'Photos: "Families Belong Together" rally held in downtown Greenville',
#  '"Families belong together" rally',
#  'From best sellers to quieter options, a guide to buying fireworks',
#  'Greer looks to the future as work begins on a new look for downtown',
#  'Photos: 1958 Miss South Carolina pageant',
#  'Clemson convenience store death investigated by SLED',
#  '5 things about Brandon Brown, Democratic candidate for SC&apos;s 4th Congressional District',
# ...
#  'Furman brings in sheep for solar farm maintenance',
#  'South Carolina Legislature overrides McMaster&apos;s veto of 15% SCE&G rate cut',
#  'Dale Westermeier, who helped keep Greenville green, is retiring after more than 30 years',
#  'Storytellers: What was your greatest moment in sports and how did it change your life?',
#  'GE reshaping likely won&apos;t be felt in the Upstate as company focuses on power, aviation',
#  'SLED is investigating the death of a man at 711 in Clemson',
#  'Annapolis shooting: At least 5 dead, police say; shooter identified',
#  'Greenville County gets a new lead public defender after a quarter-century. He has his hands full',
#  'Suspects arrested after remains found in missing woman investigation',
#  'Stacy Carmack &apos;potentially overdosed&apos; before her body was burned, authorities say',
#  'Baby girl surrendered to Greenville Memorial Hospital under Daniel&apos;s Law',
#  'Greenville abortion provider fined $19,000 for violating South Carolina waste laws',
#  'The Greenville News rolls out a new website today &ndash; here&apos;s what you can expect!',
#  'The Greenville News rolls out new web design',
#  'Greenville babysitter in jail accused of molesting girl under age 11',
#  'Elderly couple receive a refrigerator from AIM and Electrolux',
#  'Shooting in Anderson with investigation at Plez U and Woodland Apts',
#  'Mystery London jogger shoved woman into path of bus. The case is now closed &mdash; and unsolved.',
#  'Greenville rally planned to protest &apos;malicious mistreatment of immigrants&apos; at U.S.-Mexico border',
#  'Lockheed Martin F-16 production expected to create hundreds of jobs in Greenville',
#  'Nikki Haley, on an official visit to her parents&apos; native India, tours temples, church and a mosque',
#  'Former SC governor Nikki Haley visits India',
#  'Here are 4 hikes in the Upstate to cool you down',
#  'Photos: Memories of Summertime and Fourth of July celebrations',
#  'Part II: The Barnett-Leon plan would fix our immigration problem at its root, not at our border',
#  'South Carolina lawmakers make last-minute deal to cut SCE&G power bills, pass other nuclear laws',
#  'South Carolina teachers expected to get a pay raise this year. Here&apos;s how much',
#  'Ask LaFleur: Can you investigate status of Cherrydale Starbucks?',
#  'Power outages can become more than an inconvenience when temperatures are in the 90s',
#  'Hemp in SC: State is seeking more farmers for industrial production',
#  'Suspects brought meth from Atlanta to sell in Upstate, U.S. Attorney&apos;s Office says',
#  'Duke Energy reporting multiple power outages in Upstate following afternoon storm',
#  'Wednesday afternoon storm in Upstate',
#  'Greenville bank robbery suspect found sitting in lobby, arrested',
#  'Photos: Miss South Carolina contestants of the past',
#  '3 restaurant franchises have big plans for the Upstate',
#  'Summer showers and summer flowers',
#  'How to help Capital Gazette journalists after the Annapolis newsroom shooting',
#  'Mauldin woman killed in Spartanburg County wreck',
#  'Families Belong Together Rally',
#  'Hundreds gather in Sioux Falls to protest family separation at the border',
#  'Platte-area woman found not guilty on all charges in trial stemming from Gear Up scandal',
#  'Argus All-Access: March to Madness',
#  'Argus All-Access: March to Madness (Episode 9, Dawn Seiler)',
#  'Argus All-Access: March to Madness (Episode 8, Yotes & Tanagers)',
#  'Argus All-Access: March to Madness (Episode 7, Part 1)',
#  'Photos: Families Belong Together Rally',
#  'Wells Fargo requests foreclosure on Rapid City mall',
#  'Why did Sioux Falls approve a winery in Western Mall but no alcohol in the movie theater?',
#  'Police: 26-year-old stabbed near northeast Sioux Falls',
#  'Struggling to get pregnant',
#  'Where to watch fireworks this Fourth of July, and other festivities',
#  'Global Aquaponics exec Tim Burns faces charges for writing $22,500 in bad checks to Pizza Ranch owner',
#  'The Bible gives a picture of God you can trust',
#  'Swim school for young children coming to southern Sioux Falls',
#  'New South Dakota laws will impact renters, brewers and inmates',
#  'Land surveyors work at 85th Street and Minnesota Avenue in Sioux Falls',
#  'Questions about fireworks? We&apos;ve got answers.',
#  'Great Plains Zoo offers free Sunday admission for 2 hours',
#  'Levitt at the Falls announces first CEO',
#  'Here&apos;s what&apos;s happening in Sioux Falls this weekend',
#  'Growing pains: Sanford&apos;s aggressive growth beyond Sioux Falls not always an easy path',
#  'Sanford CEO teases deal in Chicago market, suggesting even more growth for the system',
#  'Central Payments to double size of Dell Rapids HQ and add jobs',
#  'WATCH: Superheroes on Sanford Children&apos;s Hospital washing windows, delighting kids',
#  'Wild June weather showers eastern South Dakota with half of annual rainfall in two weeks',
#  'Supt. Maher talks Ivanka Trump, Betsy DeVos and the future of STEM education in South Dakota',
#  'Photos: Southeast Tech land surveying',
#  'How many civil rights violations has your school district had recently?',
#  'Authorities: Man spied on minors using hidden camera',
#  'Photos: Superheroes spotted cleaning windows at Sanford',
#  'Photos: CrimeStoppers of the Sioux Empire Unsolved Crimes June 2018',
#  'Photos: The Goodyear Blimp in Sioux Falls',
#  'Photos: New Avera helicopter over Sioux Falls',
#  'Photos: Made By Thaw design work',
#  'Here&apos;s why caped superheroes were on the walls of the Sanford Children&apos;s Hospital',
#  'South Dakota Supreme Court affirms use of electronic warrants',
#  'What lessons can Memphis learn from an explorer and mapmaker?',
#  'Everything you need to know about what Memphis&apos; Beale Street has to offer',
#  'The silent breast pump is so quiet you can apparently nap while using',
#  'A tour of Beale Street in Memphis',
#  'Miss Tennessee Christine Williamson: Through the years',
#  'Where are they now? Before and after of a few Miss Tennessee winners',
#  'Eye Institute grants improved vision to Memphians',
#  'Best summer cocktails: 7 recipes to keep you in good spirits',
#  'Haslam discusses achievements, expectations during Collierville event',
#  'Does posting calorie counts on menus make a difference?',
#  'Memphis Literary Arts Festival: Not your traditional book festival',
#  'Inaugural Camp DJ Memphis builds confidence, new skills',
#  'Lashara Wheeler saves eight ducklings in drain, named Peabody honorary duckmaster',
#  'Son&apos;s diagnosis prompts Bartlett doctor&apos;s fight against diabetes',
#  'We can all learn something from the Bar-Kays&apos; story',
#  'Sand and a splash of sun as Germantown hosts beach party',
#  'Josh Steiner opens Strano by Chef Josh in East Memphis',
#  'National Doughnut Day: Where to find freebies and deals in Memphis',
#  'New movies in Memphis and special screenings, June 1-7',
#  'From Playhouse on the Square to New York: Memphian uses acting to engage communities',
#  'Synagogue members follow command to gather food and serve families',
#  'Explore Bike Share: How to sign up and explore Memphis',
#  'Explore Bike Share in South Memphis',
#  'Trouble at the dock: Locking community bikes',
#  'Miss Tennessee Scholarship Pageant Over the Years',
#  'Before prom, a send off celebration',
#  'KIPP:Memphis Collegiate High School - 2018 Decision Day',
#  'Botanic Gardens hosts a celebration of mom',
#  'Families flock to Shelby Farms strawberry field',
#  'A grape tradition: Restaurants battle for bragging rights on Beale',
#  'Here&apos;s what new Tennessee opioid restrictions mean at your doctor&apos;s office and pharmacy',
#  'Records: Same toxic coal ash, different EPA treatment of workers in Alabama, Tennessee',
#  'Knoxville Police Department offers active shooter tips following Capital Gazette shooting',
#  'Haslam signs TN Together, gives lifeline to state beset by opioid epidemic',
#  'Capital Gazette editor Rick Hutzell earned degree from The University of Tennessee',
#  'Former UT football quarterback motivates youth at Save Our Sons Summit',
#  'KPD: Be wary of catalytic converter thefts',
#  'Shoplifting suspect dies, other driver runs after head-on crash, police say',
#  'Three women accused this Pellissippi professor of sexual harassment. He still has his job.',
#  'Parents of Blount man facing child porn charges urge pre-trial release for his safety',
#  'White nationalist arrested at Knox Pridefest once helped try to take over North Dakota town',
#  'Carter High School through the years',
#  'THP: 3 killed, several injured in Rogersville following rollover crash',
#  'Gentle Barn animal rescue meets $600K fundraising goal, to open in August',
#  'Man shot in his home in South Knoxville',
#  'Former UT Vol DJ Sterl the Pearl gives impassioned speech to motivate youth at Save Our Sons Summit',
#  'Former Vol DJ Sterl the Pearl motivates youth at Save Our Sons Summit',
#  'Gov. Bill Haslam on new TN Together opioid law',
#  'Photographer&apos;s tips for better iPhone fireworks photos',
#  'Looking back at Rule High School',
#  'Two new Knox County middle schools almost ready to open',
#  'Tennessee&apos;s governors through the years',
#  'Knoxville Biz Ticker: SmartFinancial, Inc. to acquire Foothills Bancorp, Inc.',
#  'KPD, FBI investigate bank robbery in downtown Knoxville',
#  'House fire kills three dogs in North Knox',
#  'Knoxville physician charged with assault outside Blackburn campaign event at Market Square',
#  'Diane Black takes swipes at Randy Boyd, Bill Lee in her first attack ad of governor&apos;s race',
#  'Randy Boyd joins Diane Black in support of expanded I-840 as possible transportation fix',
#  'Knox man accused of carjacking woman in wheelchair booked into jail',
#  'Central High School through the years',
#  'Families Belong Together: Knoxville rally among nationwide protests Saturday',
#  'Jury brands Craigslist slaying suspect guilty of killing but not plotting death',
#  'Take a look inside the new Hardin Valley and Gibbs middle schools',
#  'Elkmont Campground reopens after evacuation due to flooding',
#  'Construction nearly complete for Hardin Valley, Gibbs middle schools',
#  'Bill Lee speaking at SoKno Market in Knoxville',
#  'Total Wine opens in Turkey Creek',
#  '4th of July travel forecast: Low gas prices will send more travelers on road trips',
#  'Flooding closes areas of Great Smoky Mountains National Park',
#  'PHOTOS: Elkmont Clubhouse, cabins & campground in the Smoky Mountains',
#  'Pellissippi State professor accused of sexual harassment',
#  'Randy Boyd campaign received more than $90,000 in donations from people at companies that received state grants',
#  'Bearden High School through the years',
#  'TBI searching for missing, endangered 16-year-old Tennessee girl',
#  'Jewelry TV host Misty Mills branches out with Merelli&apos;s Italian dining in Bearden',
#  'Knoxville restaurant owner reacts to travel ban, reflects on his own mission as Syrian refugee',
#  'See Inside: Margaritaville Resort Gatlinburg opens Thursday',
#  'How to help Capital Gazette journalists after the Annapolis newsroom shooting',
#  'Here&apos;s what consolidated Clarksville-Montgomery County government would look like',
#  'Justin Kanew finishes &apos;Amazing Race&apos; tour of District 7 with Clarksville show',
#  'Candidate debates coming up from Clarksville Association of Realtors',
#  'Pass and Go winner phones home',
#  'Amazing Race Montgomery County',
#  'Capital Gazette editor Rick Hutzell earned degree from The University of Tennessee',
#  'God and Country returns for 30th July Fourth on the air',
#  'Here&apos;s what new Tennessee opioid restrictions mean at your doctor&apos;s office and pharmacy',
#  'Tennessee&apos;s governors through the years',
#  'Why Clarksville can&apos;t ban panhandling, and why tickets don&apos;t work',
#  'Woman dies after being thrown from van in DUI wreck in Clarksville',
#  'Fatal crash in Clarksville',
#  'Diane Black takes swipes at Randy Boyd, Bill Lee in her first attack ad of governor&apos;s race',
#  'Randy Boyd joins Diane Black in support of expanded I-840 as possible transportation fix',
#  'Consolidation blueprint finalized, with a few last-minute tweaks',
#  'Nashville&apos;s Fourth of July concert and fireworks display: Everything you need to know',
#  'Fireworks near me in Clarksville: Where to watch fireworks around town',
#  'Randy Boyd campaign received more than $90,000 in donations from people at companies that received state grants',
#  'Vote in an online poll: What should be done about panhandling?',
#  'What the voting records reveal about Tennessee&apos;s candidates for governor',
#  'Civil War diary uncovered in Clarksville, includes secret Union plans',
#  'Civil War diary of Eleanora Willauer',
#  'Downtown development group TRC sets $300,000 fundraising goal',
#  'AAU boys basketball tournament returning to Clarksville',
#  'Where to watch 4th of July fireworks in Nashville and Middle Tennessee',
#  'Diane Black, Bill Lee want to change the way Tennessee&apos;s AG is selected',
#  'Panhandling on rise in Clarksville, but city has plan to push it down',
#  'Panhandlers in Clarksville',
#  'Tennessee&apos;s children see improvements in education, health in latest KIDS COUNT report',
#  'MTSU in talks with Valparaiso University to move law school to Murfreesboro',
#  'Vote on who should get the next Clarksville statue',
#  'Bredesen speaks in Clarksville',
#  'David Rausch is sworn as TBI director',
#  'Dotsonville barbecue 2018',
#  'Water fun in Big West Fork Creek',
#  '2018 Tennessee governor&apos;s race forums',
#  'Leaf-Chronicle Archives',
#  'Local Public Notices',
#  'Protesters: Stop family separation, get out and vote',
#  'Family separation protest at the Madison County Courthouse',
#  'Family separation protest in Jackson',
#  'Letters to the editor',
#  'Capital Gazette editor Rick Hutzell earned degree from The University of Tennessee',
#  'Woman injured when gun goes off in Lexington Wal-Mart',
#  'VIDEO: Tyler Building Construction Time Lapse',
#  'VIDEO: House of Horror in Bells',
#  'VIDEO: TBI special agent killed in Jackson',
#  'VIDEO: Grace Burgess starts Miss Tennessee reign',
#  'Madison County Fire Dept. wins annual Battle of the Badges trophy',
#  'GALLERY: Daughters of the American Revolution Field of Flags 2018',
#  'Here&apos;s what new Tennessee opioid restrictions mean at your doctor&apos;s office and pharmacy',
#  'Madison County Commission approves $228.6M budget for 2018-19 fiscal year, no tax increase',
#  'Tennessee&apos;s governors through the years',
#  '2 arrested on meth charges in Weakley County',
#  'Diane Black takes swipes at Randy Boyd, Bill Lee in her first attack ad of governor&apos;s race',
#  'Randy Boyd joins Diane Black in support of expanded I-840 as possible transportation fix',
#  'Tyler Spann: Gone too soon',
#  'Jackson Christian student dies in boating accident',
#  'GALLERY: Visitation for Tyler Spann at Lexington High School',
#  'The making of a family',
#  'Do you want to make smarter gardening choices?',
#  'Elkmont Campground reopens after evacuation due to flooding',
#  'Trinity Christian Academy announces new&nbsp;Upper School principal',
#  'Camp Imaginarium gives local children Down syndrome a camp of their own',
#  'Humboldt&apos;s Stigall Center getting a facelift',
#  'GALLERY: Rockabilly Grand Prix',
#  '300 cyclists, 66 miles',
#  'Jackson police seek ID in Holiday Inn Express theft',
#  'A new therapy: microneedling facials',
#  'Construction won&rsquo;t slow July 4th travelers in Tennessee',
#  'Randy Boyd campaign received more than $90,000 in donations from people at companies that received state grants',
#  'What the voting records reveal about Tennessee&apos;s candidates for governor',
#  'PEOPLE GALLERY: 2018 Miss Tennessee Scholarship Pageant Saturday Night',
#  'PEOPLE GALLERY: 2018 Miss Tennessee Scholarship Pageant Fri. Night',
#  'David Rausch is sworn as TBI director',
#  'GALLERY: Miss Tennessee 2018 Christine Williamson',
#  'GALLERY: Miss Tennessee 2018 Scholarship Pageant Crowning Night',
#  'Coupons help mom through poverty',
#  'Spanish, Urdu & Thai: Students learn English at school',
#  '&apos;Cousin Tuny&apos; dies at 91',
#  'Sentencing laws anger victim&rsquo;s family',
#  ...]
